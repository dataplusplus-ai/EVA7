# %% [markdown]
# <a href="https://colab.research.google.com/github/dataplusplus-ai/EVA7/blob/main/11_yolo/custom_yolov3_training/YoloV3_CustomData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Result of running YoloV3 on 3032 images with 10 epochs to locate the objects mask,boots,vest,hardhat

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cat /content/drive/MyDrive/malathi/YoloV3/data/customdata/custom.data
# Out:
# classes=4
# train=data/customdata/train.txt
# valid=data/customdata/test.txt
# names=data/customdata/custom.names

# %%
import time
import glob
import torch
import os
import warnings
warnings.filterwarnings('ignore')

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
# %cd /content/drive/MyDrive/malathi/YoloV3
# Out:
# /content/drive/MyDrive/malathi/YoloV3

# %%
# !ls /content/drive/MyDrive/malathi/YoloV3
# Out:
#  annotation_tool	      output1	      test.py
#  cfg			      output_images   ting
#  data			      __pycache__     train.py
#  detect.py		      README.md      'ubdivisions=1'
#  follow_safety_video_output   results.json    utils
#  models.py		      results.png     vim.exe.stackdump
#  output			      runs	      weights

# %%
#classes=4
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 10
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=10, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2863 found, 131 missing, 38 empty, 0 duplicate, for 3032 images): 100% 3032/3032 [07:47<00:00,  6.49it/s]
# Caching images (1.7GB): 100% 3032/3032 [08:55<00:00,  5.67it/s]
# ...

# %%
# !python detect.py --conf-thres 0.3 --source "/content/drive/MyDrive/malathi/YoloV3/output_images" --output images_output
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='images_output', save_txt=False, source='/content/drive/MyDrive/malathi/YoloV3/output_images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/16 /content/drive/MyDrive/malathi/YoloV3/output_images/image (1).jpg: 384x512 1 bootss, Done. (0.108s)
# ...

# %%
# !python detect.py --conf-thres 0.3 --source "/content/drive/MyDrive/malathi/YoloV3/data/follow_safety.mp4" --output output1
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output1', save_txt=False, source='/content/drive/MyDrive/malathi/YoloV3/data/follow_safety.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# video 1/1 (1/360) /content/drive/MyDrive/malathi/YoloV3/data/follow_safety.mp4: 320x512 Done. (0.083s)
# ...

# %%
w=500
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (1).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (2).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (3).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (4).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (5).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (6).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (7).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (8).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (9).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (10).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (11).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (12).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (13).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (14).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (15).jpg',width=w)

# %%
Image(filename='/content/drive/MyDrive/malathi/YoloV3/images_output/image (16).jpg',width=w)
